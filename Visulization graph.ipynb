# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
<img src='file.jpeg'>
# Out:
#   Cell In[46], line 1
#     <img src='file.jpeg'>
#     ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv('practice.csv')
df.head(1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
#
#    body_mass_g   sex
# 0       3750.0  Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.dropna()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# # Frequency Distribution (histplot,distplot,displot

# %%
df['bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339     NaN
# 340    46.8
# 341    50.4
# 342    45.2
# 343    49.9
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
plt.figure(figsize=(4,3))
sns.distplot(df['bill_length_mm'])
# Out:
# C:\Users\N\AppData\Local\Temp\ipykernel_8404\3837149603.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bill_length_mm'])
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %%
plt.figure(figsize=(4,4))
sns.histplot(df['bill_length_mm'])
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
plt.figure(figsize=(4,4))
sns.displot(df['bill_length_mm'],kde=True)

# %%
plt.figure(figsize=(4,2))
sns.displot(df['bill_length_mm'],bins=[32,36,40,44,48,52])

# %%
plt.figure(figsize=(4,2))
sns.displot(df['bill_length_mm'],rug=True)

# %%
x=np.random.randint(39,99,155)
x
# Out:
# array([58, 68, 72, 78, 72, 74, 69, 98, 73, 76, 77, 54, 53, 74, 91, 86, 84,
#        65, 98, 54, 79, 41, 84, 96, 71, 95, 84, 46, 87, 49, 42, 40, 53, 53,
#        72, 57, 45, 64, 86, 73, 69, 43, 75, 77, 65, 90, 58, 62, 96, 41, 95,
#        75, 72, 75, 78, 73, 42, 50, 71, 68, 65, 97, 76, 64, 85, 47, 96, 75,
#        95, 73, 95, 46, 56, 65, 98, 79, 90, 73, 51, 62, 76, 62, 82, 69, 73,
#        81, 56, 79, 62, 93, 48, 88, 98, 52, 78, 71, 72, 61, 81, 96, 39, 39,
#        46, 46, 77, 51, 72, 48, 83, 63, 73, 76, 56, 94, 82, 87, 60, 77, 70,
#        64, 42, 84, 69, 43, 55, 65, 77, 98, 48, 68, 79, 92, 46, 44, 97, 94,
#        46, 43, 60, 97, 70, 45, 70, 61, 68, 47, 39, 41, 54, 47, 39, 67, 65,
#        63, 90])

# %%
sns.distplot(x,bins=[40,50,60,70,80])
# Out:
# C:\Users\N\AppData\Local\Temp\ipykernel_8404\2094444641.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x,bins=[40,50,60,70,80])
# <Axes: ylabel='Density'>

# %%
sns.displot(df['bill_length_mm'],rug=True,color='g')

# %%
plt.figure(figsize=(4,2))
sns.displot(df['bill_length_mm'],rug=True, log_scale=True)

# %%
plt.figure(figsize=(4,3))
x=[6,35,560,1240]
sns.distplot(x)
# Out:
# C:\Users\N\AppData\Local\Temp\ipykernel_8404\4043509959.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(4,3))
x=np.random.randint(1,10000,150)
sns.distplot(x)
plt.show()
# Out:
# C:\Users\N\AppData\Local\Temp\ipykernel_8404\2005822533.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)

# %% [markdown]
# # Line plot

# %%
plt.figure(figsize=(4,3))
roll=[1,2,3,4,5,]
marks=[69, 82, 73, 79, 83]
df1=pd.DataFrame({'Roll No':roll,'Marks':marks})
sns.lineplot(x='Roll No',y='Marks',data=df1)
# Out:
# <Axes: xlabel='Roll No', ylabel='Marks'>

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
plt.figure(figsize=(4,3))
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data=df,hue='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
df1=df.head(75)

# %%
plt.figure(figsize=(4,3))
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data=df,hue='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
plt.figure(figsize=(4,3))
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data=df,style='island')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
plt.figure(figsize=(4,3))
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data=df,hue='sex',style='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data=df,hue='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data=df,hue='sex',style='sex',
             markers=['^','o'])
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data=df,hue='island',style='island',
             markers=['^','o','>'],palette='Pastel2')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.set_style('dark') 
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data=df,hue='island',style='island',
             markers=['^','o','>'],palette='Pastel2')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.set_style('white') 
#white,whitegrids, dark, darkgrids, ticks
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data=df,hue='island',style='island',
             markers=['^','o','>'],palette='Pastel2')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# # Barplot

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.set_style('darkgrid')
sns.barplot(x='sex',y='body_mass_g',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %%
sns.set_style('darkgrid')
sns.barplot(x='island',y='bill_depth_mm',data=df)
# Out:
# <Axes: xlabel='island', ylabel='bill_depth_mm'>

# %%
sns.set_style('darkgrid')
sns.barplot(x='island',y='bill_depth_mm',data=df,,palette='copper')
# Out:
# <Axes: xlabel='island', ylabel='bill_depth_mm'>

# %%
sns.set_style('darkgrid')
sns.barplot(x='island',y='bill_depth_mm',
            data=df,hue='sex',
            palette='copper',
            order:['Torgersen','Dream','Biscoe'],
            saturation=0.25,ci=100)
# Out:
#   Cell In[128], line 4
#     order:['Torgersen','Dream','Biscoe'],saturation=0.25,ci=100)
#          ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.pairplot(df)
